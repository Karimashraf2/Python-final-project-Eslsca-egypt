# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
X = pd.read_csv("data.csv")
X
# Out:
#                                                   title  rating review_date  \
# 0     "Will honestly never fly them again if I can h...       4  19/11/2022
# 1     "Very unprofessional for a renowned airline li...       1  19/11/2022
# 2                 "lounge was overcrowded and worn out"       2  18/11/2022
# 3                             "very uncomfortable trip"       1  07/11/2022
# 4                "rate this just as a mediocre journey"       5  07/11/2022
# ...                                                 ...     ...         ...
# 1195              "nice flight with good cabin service"       9  11/09/2017
# 1196                   "they are just an embarrassment"       2  11/09/2017
# 1197                           "very good flight again"       8  09/09/2017
# 1198                         "expensive at £343 return"       8  09/09/2017
# 1199                    "staff were extremely friendly"       8  09/09/2017
#
#                                                  review  trip_verified  \
# 0     Flew from Amman to London on Nov. 14 2022. Not...           True
# 1     This is the worst experience I have ever had w...           True
# 2     Flying LHR T5 to CPT November 2022:  BA app an...           True
# 3     Not Verified | Worst experience ever. Outbound...          False
# 4     Check in was a shambles at BWI, just 3 counter...           True
# ...                                                 ...            ...
# 1195  ✅ Verified Review |  London Heathrow to Biarri...          False
# 1196  ✅ Verified Review |  London Gatwick to Funchal...          False
# 1197  ✅ Verified Review |  Zakinthos to London Heath...          False
# 1198  ✅ Verified Review |  Flew British Airways from...          False
# 1199  ✅ Verified Review |  Toronto to London Heathro...          False
#
#             aircraft type_of_traveller        seat_type  \
# 0                NaN      Solo Leisure  Premium Economy
# 1                NaN      Solo Leisure    Economy Class
# 2         Boeing 777      Solo Leisure   Business Class
# 3                NaN      Solo Leisure    Economy Class
# 4       Boeing 787-8      Solo Leisure    Economy Class
# ...              ...               ...              ...
# 1195            A319    Couple Leisure    Economy Class
# 1196            A320    Couple Leisure    Economy Class
# 1197            A320    Family Leisure   Business Class
# 1198            A319          Business    Economy Class
# 1199  Boeing 777-200          Business   Business Class
#
#                                      route date_flown  seat_comfort  \
# 0     Amman Jordan to London UK (Heathrow)     Nov-22           3.0
# 1     Dusseldorf to London via Los Angeles     Aug-22           1.0
# 2                      London to Cape Town     Nov-22           4.0
# 3              Milan to Dallas via London      Nov-22           2.0
# 4             Baltimore to London Heathrow     Nov-22           1.0
# ...                                    ...        ...           ...
# 1195           London Heathrow to Biarritz     Sep-17           4.0
# 1196             London Gatwick to Funchal     Sep-17           1.0
# 1197          Zakinthos to London Heathrow     Sep-17           4.0
# 1198       Belfast City to London Heathrow     Sep-17           3.0
# 1199            Toronto to London Heathrow     Sep-17           4.0
#
#       cabin_staff_service                food_and_beverages  ground_service  \
# 0                     2.0                               NaN             4.0
# 1                     1.0  <span class="star fill">1</span>             1.0
# 2                     2.0  <span class="star fill">4</span>             1.0
# 3                     5.0  <span class="star fill">2</span>             2.0
# 4                     3.0  <span class="star fill">1</span>             2.0
# ...                   ...                               ...             ...
# 1195                  5.0                               NaN             4.0
# 1196                  1.0                               NaN             2.0
# 1197                  5.0  <span class="star fill">2</span>             2.0
# 1198                  4.0                               NaN             5.0
# 1199                  5.0                               NaN             4.0
#
#       value_for_money  wifi_and_connecticity  recommend  wifi_and_connectivity
# 0                   2                    NaN      False                    NaN
# 1                   1                    NaN      False                    1.0
# 2                   1                    NaN      False                    NaN
# 3                   1                    NaN      False                    2.0
# 4                   3                    NaN       True                    NaN
# ...               ...                    ...        ...                    ...
# 1195                4                    NaN       True                    NaN
# 1196                1                    NaN      False                    NaN
# 1197                5                    NaN       True                    NaN
# 1198                2                    NaN       True                    NaN
# 1199                4                    NaN       True                    NaN
#
# [1200 rows x 18 columns]

# %%
X.shape
# Out:
# (1200, 18)

# %%
X.head()
# Out:
#                                                title  rating review_date  \
# 0  "Will honestly never fly them again if I can h...       4  19/11/2022
# 1  "Very unprofessional for a renowned airline li...       1  19/11/2022
# 2              "lounge was overcrowded and worn out"       2  18/11/2022
# 3                          "very uncomfortable trip"       1  07/11/2022
# 4             "rate this just as a mediocre journey"       5  07/11/2022
#
#                                               review  trip_verified  \
# 0  Flew from Amman to London on Nov. 14 2022. Not...           True
# 1  This is the worst experience I have ever had w...           True
# 2  Flying LHR T5 to CPT November 2022:  BA app an...           True
# 3  Not Verified | Worst experience ever. Outbound...          False
# 4  Check in was a shambles at BWI, just 3 counter...           True
#
#        aircraft type_of_traveller        seat_type  \
# 0           NaN      Solo Leisure  Premium Economy
# 1           NaN      Solo Leisure    Economy Class
# 2    Boeing 777      Solo Leisure   Business Class
# 3           NaN      Solo Leisure    Economy Class
# 4  Boeing 787-8      Solo Leisure    Economy Class
#
#                                   route date_flown  seat_comfort  \
# 0  Amman Jordan to London UK (Heathrow)     Nov-22           3.0
# 1  Dusseldorf to London via Los Angeles     Aug-22           1.0
# 2                   London to Cape Town     Nov-22           4.0
# 3           Milan to Dallas via London      Nov-22           2.0
# 4          Baltimore to London Heathrow     Nov-22           1.0
#
#    cabin_staff_service                food_and_beverages  ground_service  \
# 0                  2.0                               NaN             4.0
# 1                  1.0  <span class="star fill">1</span>             1.0
# 2                  2.0  <span class="star fill">4</span>             1.0
# 3                  5.0  <span class="star fill">2</span>             2.0
# 4                  3.0  <span class="star fill">1</span>             2.0
#
#    value_for_money  wifi_and_connecticity  recommend  wifi_and_connectivity
# 0                2                    NaN      False                    NaN
# 1                1                    NaN      False                    1.0
# 2                1                    NaN      False                    NaN
# 3                1                    NaN      False                    2.0
# 4                3                    NaN       True                    NaN

# %%
X.tail()
# Out:
#                                       title  rating review_date  \
# 1195  "nice flight with good cabin service"       9  11/09/2017
# 1196       "they are just an embarrassment"       2  11/09/2017
# 1197               "very good flight again"       8  09/09/2017
# 1198             "expensive at £343 return"       8  09/09/2017
# 1199        "staff were extremely friendly"       8  09/09/2017
#
#                                                  review  trip_verified  \
# 1195  ✅ Verified Review |  London Heathrow to Biarri...          False
# 1196  ✅ Verified Review |  London Gatwick to Funchal...          False
# 1197  ✅ Verified Review |  Zakinthos to London Heath...          False
# 1198  ✅ Verified Review |  Flew British Airways from...          False
# 1199  ✅ Verified Review |  Toronto to London Heathro...          False
#
#             aircraft type_of_traveller       seat_type  \
# 1195            A319    Couple Leisure   Economy Class
# 1196            A320    Couple Leisure   Economy Class
# 1197            A320    Family Leisure  Business Class
# 1198            A319          Business   Economy Class
# 1199  Boeing 777-200          Business  Business Class
#
#                                 route date_flown  seat_comfort  \
# 1195      London Heathrow to Biarritz     Sep-17           4.0
# 1196        London Gatwick to Funchal     Sep-17           1.0
# 1197     Zakinthos to London Heathrow     Sep-17           4.0
# 1198  Belfast City to London Heathrow     Sep-17           3.0
# 1199       Toronto to London Heathrow     Sep-17           4.0
#
#       cabin_staff_service                food_and_beverages  ground_service  \
# 1195                  5.0                               NaN             4.0
# 1196                  1.0                               NaN             2.0
# 1197                  5.0  <span class="star fill">2</span>             2.0
# 1198                  4.0                               NaN             5.0
# 1199                  5.0                               NaN             4.0
#
#       value_for_money  wifi_and_connecticity  recommend  wifi_and_connectivity
# 1195                4                    NaN       True                    NaN
# 1196                1                    NaN      False                    NaN
# 1197                5                    NaN       True                    NaN
# 1198                2                    NaN       True                    NaN
# 1199                4                    NaN       True                    NaN

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1200 entries, 0 to 1199
# Data columns (total 18 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   title                  1200 non-null   object
#  1   rating                 1200 non-null   int64
#  2   review_date            1200 non-null   object
#  3   review                 1200 non-null   object
#  4   trip_verified          1200 non-null   bool
#  5   aircraft               720 non-null    object
#  6   type_of_traveller      1199 non-null   object
#  7   seat_type              1200 non-null   object
#  8   route                  1198 non-null   object
#  9   date_flown             1200 non-null   object
#  10  seat_comfort           1124 non-null   float64
#  11  cabin_staff_service    1117 non-null   float64
#  12  food_and_beverages     670 non-null    object
#  13  ground_service         1147 non-null   float64
#  14  value_for_money        1200 non-null   int64
#  15  wifi_and_connecticity  0 non-null      float64
#  16  recommend              1200 non-null   bool
#  17  wifi_and_connectivity  287 non-null    float64
# dtypes: bool(2), float64(5), int64(2), object(9)
# memory usage: 152.5+ KB

# %%
X.describe()
# Out:
#             rating  seat_comfort  cabin_staff_service  ground_service  \
# count  1200.000000   1124.000000          1117.000000     1147.000000
# mean      4.397500      2.782028             3.179946        2.782040
# std       3.238554      1.377079             1.526595        1.486856
# min       1.000000      1.000000             1.000000        1.000000
# 25%       1.000000      1.000000             2.000000        1.000000
# 50%       3.000000      3.000000             3.000000        3.000000
# 75%       8.000000      4.000000             5.000000        4.000000
# max      10.000000      5.000000             5.000000        5.000000
#
#        value_for_money  wifi_and_connecticity  wifi_and_connectivity
# count      1200.000000                    0.0             287.000000
# mean          2.530833                    NaN               2.149826
# std           1.468848                    NaN               1.482482
# min           1.000000                    NaN               1.000000
# 25%           1.000000                    NaN               1.000000
# 50%           2.000000                    NaN               1.000000
# 75%           4.000000                    NaN               3.000000
# max           5.000000                    NaN               5.000000

# %%
X.isnull().sum()
# Out:
# title                       0
# rating                      0
# review_date                 0
# review                      0
# trip_verified               0
# aircraft                  480
# type_of_traveller           1
# seat_type                   0
# route                       2
# date_flown                  0
# seat_comfort               76
# cabin_staff_service        83
# food_and_beverages        530
# ground_service             53
# value_for_money             0
# wifi_and_connecticity    1200
# recommend                   0
# wifi_and_connectivity     913
# dtype: int64

# %%
X.columns
# Out:
# Index(['title', 'rating', 'review_date', 'review', 'trip_verified', 'aircraft',
#        'type_of_traveller', 'seat_type', 'route', 'date_flown', 'seat_comfort',
#        'cabin_staff_service', 'food_and_beverages', 'ground_service',
#        'value_for_money', 'wifi_and_connecticity', 'recommend',
#        'wifi_and_connectivity'],
#       dtype='object')

# %%
class DataProcessor:
    def __init__(self, filename):
        self.filename = filename
        
    def load_data(self):
        df = pd.read_csv(self.filename)
        return df
    
    def clean_data(self, data):
        remove_col = ['food_and_beverages', 'wifi_and_connecticity', 'wifi_and_connectivity']
        data = data.drop(remove_col, axis=1)

        data = data.dropna()
        
        data = data.reset_index(drop=True)
        
        return data

# %%
data_processor = DataProcessor('data.csv')

data = data_processor.load_data()

clean_data = data_processor.clean_data(data)

# %%
clean_data.columns
# Out:
# Index(['title', 'rating', 'review_date', 'review', 'trip_verified', 'aircraft',
#        'type_of_traveller', 'seat_type', 'route', 'date_flown', 'seat_comfort',
#        'cabin_staff_service', 'ground_service', 'value_for_money',
#        'recommend'],
#       dtype='object')

# %%
clean_data.shape
# Out:
# (712, 15)

# %%
clean_data.isnull().sum()
# Out:
# title                  0
# rating                 0
# review_date            0
# review                 0
# trip_verified          0
# aircraft               0
# type_of_traveller      0
# seat_type              0
# route                  0
# date_flown             0
# seat_comfort           0
# cabin_staff_service    0
# ground_service         0
# value_for_money        0
# recommend              0
# dtype: int64

# %%
class DataAnalyzer:
    
    def get_average_of_column(self, clean_data, col_1, col_2):
        monthly_avg = data.groupby(col_1)[col_2].mean().reset_index()
        return monthly_avg
    
    def get_distribution_of_column(self, clean_data, col_1):
        rating_dist = data[col_1].value_counts(normalize=False).reset_index()
        rating_dist.columns = [col_1, 'frequency']
        return rating_dist
    
    def get_median_of_column(self, clean_data, col_1):
        rating_dist = data[col_1].value_counts(normalize=False).reset_index()
        rating_dist.columns = [col_1, 'frequency']
        median_rating = np.median(data[col_1])
        return median_rating
    
    def get_mod_of_column(self, clean_data, column):
        feedback_count = data[column].value_counts().reset_index()
        feedback_count.columns = ['values', 'frequency']
        return feedback_count

# %%
analyzer = DataAnalyzer()

avg_ratings = analyzer.get_average_of_column(clean_data, 'review_date', 'rating')
rating_dist = analyzer.get_distribution_of_column(clean_data, 'rating')
median_rating = analyzer.get_median_of_column(clean_data, 'rating')
feedback_count = analyzer.get_mod_of_column(clean_data, 'value_for_money')

# %%
class DataVisualizer:
    
    def plot_line_chart(self, clean_data, num_of_col, x_column_name, y_column_name):
        d = data.head(num_of_col)
        sns.lineplot(x=x_column_name, y=y_column_name, data=d)
        plt.show()
        
    def plot_distribution(self, clean_data, column_name, num_of_bins):
        sns.histplot(data=clean_data, x=column_name, bins=num_of_bins, kde=True, color="green")
        plt.show()
    
    def plot_pie(self, clean_data, column_name):
        plt.pie(data[column_name].value_counts().values, labels=clean_data[column_name].value_counts().index)
        plt.show()
        
    def plot_scatter(self, clean_data, num_of_col, x_column_name, y_column_name, hue_col):
        d = data.head(num_of_col)
        sns.color_palette("tab10")
        sns.scatterplot(x=x_column_name, y=y_column_name, hue=hue_col, data=d)
        sns.regplot(x=x_column_name, y=y_column_name, data=data, scatter=False)
        plt.show()
        
    def heat_map(self, clean_data):
        corr = clean_data.corr()
        sns.heatmap(corr)
        plt.show()
        
    def box_plot(self, clean_data, x_column_name, y_column_name):
        sns.boxplot(x=x_column_name, y=y_column_name, data=clean_data)
        plt.show()
        
    def bar_plot(self, clean_data, num_of_col, x_column_name, y_column_name, hue_col):
        d = data.head(num_of_col)
        sns.barplot(x=x_column_name, y=y_column_name, hue=hue_col, ci=None, data=d)
        plt.show()

# %%
visualizer = DataVisualizer() 

visualizer.plot_distribution(clean_data, 'rating', 10)

# %%
visualizer.plot_distribution(clean_data, 'seat_comfort', 10)

# %%
visualizer.plot_distribution(clean_data, 'cabin_staff_service', 5)

# %%
visualizer.plot_distribution(clean_data, 'ground_service', 5)

# %%
visualizer.plot_distribution(clean_data, 'value_for_money', 20)

# %%
visualizer.plot_pie(clean_data, 'trip_verified')

# %%
visualizer.plot_pie(clean_data, 'seat_type')

# %%
visualizer.plot_scatter(clean_data, 50, 'rating', 'value_for_money', 'rating')

# %%
visualizer.plot_scatter(clean_data, 50, 'rating', 'seat_comfort', 'rating')

# %%
visualizer.plot_line_chart(clean_data, 30, 'date_flown', 'rating')

# %%
visualizer.plot_line_chart(clean_data, 712, 'rating', 'value_for_money')

# %%
visualizer.plot_line_chart(clean_data, 712, 'rating', 'ground_service')

# %%
visualizer.plot_line_chart(clean_data, 712, 'rating', 'cabin_staff_service')

# %%
visualizer.plot_line_chart(clean_data, 712, 'rating', 'seat_comfort')

# %%
visualizer.plot_line_chart(clean_data, 712, 'seat_type', 'rating')

# %%
visualizer.heat_map(clean_data)

# %%
visualizer.box_plot(clean_data, 'rating', 'value_for_money')

# %%
visualizer.bar_plot(clean_data, 10, 'rating', 'route', 'rating')

# %%
visualizer.bar_plot(clean_data, 712, 'seat_type', 'seat_comfort', 'seat_type')

# %%
visualizer.bar_plot(clean_data, 712, 'rating', 'seat_type', 'seat_type')

# %%
visualizer.bar_plot(clean_data, 712, 'rating', 'type_of_traveller', 'type_of_traveller')

# %%
visualizer.bar_plot(clean_data, 10, 'rating', 'aircraft', 'rating')
